# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=417a548e12a4700d864e5f19cc73799d

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | vao
# Processing Record 3 of Set 1 | kapit
# Processing Record 4 of Set 1 | yaan
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | novoagansk
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | adrar
# Processing Record 9 of Set 1 | port moresby
# Processing Record 10 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | nyergesujfalu
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | luebo
# Processing Record 17 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | faanui
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | namibe
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | carutapera
# Processing Record 25 of Set 1 | dzilam gonzalez
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | bikapur
# Processing Record 28 of Set 1 | saint-pierre
# Processing Record 29 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 30 of Set 1 | bethanien
# Processing Record 31 of Set 1 | peleduy
# Processing Record 32 of Set 1 | palaia fokaia
# Processing Record 33 of Set 1 | kushima
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | belaya gora
# Processing Record 38 of Set 1 | tuy hoa
# Processing Record 39 of Set 1 | adolfo lopez mateos
# Processing Record 40 of Set 1 | cayenne
# Processing Record 41 of Set 1 | cruden bay
# City not found. Skipping...
# Processing Record 42 of Set 1 | kinsale
# Processing Record 43 of Set 1 | tailai
# Processing Record 44 of Set 1 | anadyr
# Processing Record 45 of Set 1 | omboue
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | gwanda
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | kloulklubed
# Processing Record 50 of Set 1 | harnosand
# Processing Record 1 of Set 2 | matadi
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | guerrero negro
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | rome
# Processing Record 9 of Set 2 | liverpool
# Processing Record 10 of Set 2 | poum
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | bissau
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | guilin
# Processing Record 15 of Set 2 | ibra
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | bartica
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | vila
# Processing Record 21 of Set 2 | jiexiu
# Processing Record 22 of Set 2 | hasaki
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | socorro
# Processing Record 25 of Set 2 | tucurui
# Processing Record 26 of Set 2 | fairbanks
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | marabba
# Processing Record 30 of Set 2 | yantarnyy
# Processing Record 31 of Set 2 | port hardy
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | san quintin
# Processing Record 34 of Set 2 | caravelas
# Processing Record 35 of Set 2 | rawson
# Processing Record 36 of Set 2 | bilibino
# Processing Record 37 of Set 2 | kamina
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | henties bay
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | ponta delgada
# Processing Record 44 of Set 2 | harper
# Processing Record 45 of Set 2 | pevek
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | shimanovsk
# Processing Record 48 of Set 2 | yar-sale
# Processing Record 49 of Set 2 | mana
# Processing Record 50 of Set 2 | west bay
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | toropets
# Processing Record 3 of Set 3 | nanao
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | dzaoudzi
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | tarabuco
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 12 of Set 3 | fengcheng
# Processing Record 13 of Set 3 | cidreira
# Processing Record 14 of Set 3 | blackfoot
# Processing Record 15 of Set 3 | berbera
# Processing Record 16 of Set 3 | vestmannaeyjar
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | mangan
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | qaanaaq
# Processing Record 22 of Set 3 | vostok
# Processing Record 23 of Set 3 | ocos
# Processing Record 24 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 3 | rupert
# Processing Record 26 of Set 3 | airai
# Processing Record 27 of Set 3 | atherton
# Processing Record 28 of Set 3 | garzon
# Processing Record 29 of Set 3 | vanavara
# Processing Record 30 of Set 3 | haicheng
# Processing Record 31 of Set 3 | vila franca do campo
# Processing Record 32 of Set 3 | sakaiminato
# Processing Record 33 of Set 3 | pangody
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 3 | simao
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | kodiak
# Processing Record 39 of Set 3 | belawan
# Processing Record 40 of Set 3 | saint george
# Processing Record 41 of Set 3 | nhulunbuy
# Processing Record 42 of Set 3 | dikson
# Processing Record 43 of Set 3 | batagay-alyta
# Processing Record 44 of Set 3 | margate
# Processing Record 45 of Set 3 | newcastle
# Processing Record 46 of Set 3 | codrington
# Processing Record 47 of Set 3 | souillac
# Processing Record 48 of Set 3 | chapais
# Processing Record 49 of Set 3 | bredasdorp
# Processing Record 50 of Set 3 | brae
# Processing Record 1 of Set 4 | urusha
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | klaksvik
# Processing Record 4 of Set 4 | kibre mengist
# Processing Record 5 of Set 4 | otradnoye
# Processing Record 6 of Set 4 | forbes
# Processing Record 7 of Set 4 | high rock
# Processing Record 8 of Set 4 | mahebourg
# Processing Record 9 of Set 4 | tura
# Processing Record 10 of Set 4 | san cristobal
# Processing Record 11 of Set 4 | clyde river
# Processing Record 12 of Set 4 | magadan
# Processing Record 13 of Set 4 | argir
# Processing Record 14 of Set 4 | kimbe
# Processing Record 15 of Set 4 | andenes
# Processing Record 16 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 4 | kintinku
# Processing Record 18 of Set 4 | christchurch
# Processing Record 19 of Set 4 | batsfjord
# Processing Record 20 of Set 4 | talnakh
# Processing Record 21 of Set 4 | hobart
# Processing Record 22 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 4 | mayo
# Processing Record 24 of Set 4 | ribeira grande
# Processing Record 25 of Set 4 | castro
# Processing Record 26 of Set 4 | kaka
# Processing Record 27 of Set 4 | piney green
# Processing Record 28 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 4 | berdigestyakh
# Processing Record 30 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 4 | mae sai
# Processing Record 32 of Set 4 | suntar
# Processing Record 33 of Set 4 | alice springs
# Processing Record 34 of Set 4 | dossor
# Processing Record 35 of Set 4 | soyo
# Processing Record 36 of Set 4 | coquimbo
# Processing Record 37 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 4 | puksoozero
# Processing Record 39 of Set 4 | port alfred
# Processing Record 40 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 4 | aklavik
# Processing Record 42 of Set 4 | pozo colorado
# Processing Record 43 of Set 4 | nanortalik
# Processing Record 44 of Set 4 | suna
# Processing Record 45 of Set 4 | opuwo
# Processing Record 46 of Set 4 | dali
# Processing Record 47 of Set 4 | ahipara
# Processing Record 48 of Set 4 | leningradskiy
# Processing Record 49 of Set 4 | tabukiniberu
# City not found. Skipping...
# Processing Record 50 of Set 4 | kandrian
# Processing Record 1 of Set 5 | torbay
# Processing Record 2 of Set 5 | mandalgovi
# Processing Record 3 of Set 5 | ifo
# Processing Record 4 of Set 5 | marawi
# Processing Record 5 of Set 5 | bonavista
# Processing Record 6 of Set 5 | anchorage
# Processing Record 7 of Set 5 | faya
# Processing Record 8 of Set 5 | gazanjyk
# Processing Record 9 of Set 5 | esperance
# Processing Record 10 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 5 | fortuna
# Processing Record 12 of Set 5 | mabua
# Processing Record 13 of Set 5 | matamoros
# Processing Record 14 of Set 5 | svetlaya
# Processing Record 15 of Set 5 | olafsvik
# Processing Record 16 of Set 5 | saldanha
# Processing Record 17 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 5 | atambua
# Processing Record 19 of Set 5 | luderitz
# Processing Record 20 of Set 5 | buraydah
# Processing Record 21 of Set 5 | chokurdakh
# Processing Record 22 of Set 5 | kavieng
# Processing Record 23 of Set 5 | lagoa
# Processing Record 24 of Set 5 | jammalamadugu
# Processing Record 25 of Set 5 | egvekinot
# Processing Record 26 of Set 5 | viedma
# Processing Record 27 of Set 5 | codajas
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | iqaluit
# Processing Record 30 of Set 5 | geraldton
# Processing Record 31 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 33 of Set 5 | tucuma
# Processing Record 34 of Set 5 | humaita
# Processing Record 35 of Set 5 | quatre cocos
# Processing Record 36 of Set 5 | raudeberg
# Processing Record 37 of Set 5 | ca mau
# Processing Record 38 of Set 5 | tsentralnyy-kospashskiy
# City not found. Skipping...
# Processing Record 39 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 5 | constitucion
# Processing Record 41 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 5 | portland
# Processing Record 43 of Set 5 | doha
# Processing Record 44 of Set 5 | tessalit
# Processing Record 45 of Set 5 | kaitangata
# Processing Record 46 of Set 5 | ye
# City not found. Skipping...
# Processing Record 47 of Set 5 | yuli
# Processing Record 48 of Set 5 | bend
# Processing Record 49 of Set 5 | concepcion
# Processing Record 50 of Set 5 | boende
# Processing Record 1 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 6 | shingu
# Processing Record 3 of Set 6 | wanning
# Processing Record 4 of Set 6 | tautira
# Processing Record 5 of Set 6 | cabo san lucas
# Processing Record 6 of Set 6 | arrifes
# Processing Record 7 of Set 6 | gidam
# Processing Record 8 of Set 6 | sambava
# Processing Record 9 of Set 6 | nantucket
# Processing Record 10 of Set 6 | igarka
# Processing Record 11 of Set 6 | slonim
# Processing Record 12 of Set 6 | hami
# Processing Record 13 of Set 6 | potosi
# Processing Record 14 of Set 6 | hornepayne
# Processing Record 15 of Set 6 | fujin
# Processing Record 16 of Set 6 | kisanga
# Processing Record 17 of Set 6 | taoudenni
# Processing Record 18 of Set 6 | baoding
# Processing Record 19 of Set 6 | black river
# Processing Record 20 of Set 6 | padang
# Processing Record 21 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 6 | turukhansk
# Processing Record 23 of Set 6 | san patricio
# Processing Record 24 of Set 6 | tateyama
# Processing Record 25 of Set 6 | vysokogornyy
# Processing Record 26 of Set 6 | modasa
# Processing Record 27 of Set 6 | wilmington island
# Processing Record 28 of Set 6 | bavly
# Processing Record 29 of Set 6 | komsomolskiy
# Processing Record 30 of Set 6 | coihaique
# Processing Record 31 of Set 6 | mastic beach
# Processing Record 32 of Set 6 | uruzgan
# Processing Record 33 of Set 6 | odweyne
# Processing Record 34 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 6 | kieta
# Processing Record 36 of Set 6 | beringovskiy
# Processing Record 37 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 6 | salacgriva
# Processing Record 39 of Set 6 | la ronge
# Processing Record 40 of Set 6 | la asuncion
# Processing Record 41 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 6 | rypefjord
# Processing Record 43 of Set 6 | chuy
# Processing Record 44 of Set 6 | progreso
# Processing Record 45 of Set 6 | tarko-sale
# Processing Record 46 of Set 6 | paramonga
# Processing Record 47 of Set 6 | abu samrah
# Processing Record 48 of Set 6 | mizan teferi
# Processing Record 49 of Set 6 | bosobolo
# Processing Record 50 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 7 | eucaliptus
# Processing Record 2 of Set 7 | karratha
# Processing Record 3 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 7 | shetpe
# Processing Record 5 of Set 7 | parkent
# Processing Record 6 of Set 7 | pachino
# Processing Record 7 of Set 7 | fort nelson
# Processing Record 8 of Set 7 | lorengau
# Processing Record 9 of Set 7 | whyalla
# Processing Record 10 of Set 7 | isabela
# Processing Record 11 of Set 7 | flin flon
# Processing Record 12 of Set 7 | scranton
# Processing Record 13 of Set 7 | grootfontein
# Processing Record 14 of Set 7 | kawalu
# Processing Record 15 of Set 7 | sao filipe
# Processing Record 16 of Set 7 | kichera
# Processing Record 17 of Set 7 | bunia
# Processing Record 18 of Set 7 | sao felix do xingu
# Processing Record 19 of Set 7 | vestmanna
# Processing Record 20 of Set 7 | hamilton
# Processing Record 21 of Set 7 | billings
# Processing Record 22 of Set 7 | takaungu
# Processing Record 23 of Set 7 | sauda
# Processing Record 24 of Set 7 | agua verde
# Processing Record 25 of Set 7 | qaqortoq
# Processing Record 26 of Set 7 | haines junction
# Processing Record 27 of Set 7 | smirnykh
# Processing Record 28 of Set 7 | pangnirtung
# Processing Record 29 of Set 7 | san francisco
# Processing Record 30 of Set 7 | norman wells
# Processing Record 31 of Set 7 | comodoro rivadavia
# Processing Record 32 of Set 7 | ingham
# Processing Record 33 of Set 7 | kargasok
# Processing Record 34 of Set 7 | laguna
# Processing Record 35 of Set 7 | atasu
# Processing Record 36 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 7 | novyy urgal
# Processing Record 38 of Set 7 | novoilinsk
# Processing Record 39 of Set 7 | quang ngai
# Processing Record 40 of Set 7 | richards bay
# Processing Record 41 of Set 7 | los llanos de aridane
# Processing Record 42 of Set 7 | kontagora
# Processing Record 43 of Set 7 | nagato
# Processing Record 44 of Set 7 | san ramon
# Processing Record 45 of Set 7 | umm lajj
# Processing Record 46 of Set 7 | maceio
# Processing Record 47 of Set 7 | jequitinhonha
# Processing Record 48 of Set 7 | krasnoselkup
# Processing Record 49 of Set 7 | itatskiy
# Processing Record 50 of Set 7 | pa sang
# Processing Record 1 of Set 8 | mount isa
# Processing Record 2 of Set 8 | nguruka
# Processing Record 3 of Set 8 | lompoc
# Processing Record 4 of Set 8 | kruisfontein
# Processing Record 5 of Set 8 | daru
# Processing Record 6 of Set 8 | asau
# Processing Record 7 of Set 8 | kaniama
# Processing Record 8 of Set 8 | sao jose da coroa grande
# Processing Record 9 of Set 8 | xiongyue
# Processing Record 10 of Set 8 | lensk
# Processing Record 11 of Set 8 | dakar
# Processing Record 12 of Set 8 | rio gallegos
# Processing Record 13 of Set 8 | itaituba
# Processing Record 14 of Set 8 | sesheke
# Processing Record 15 of Set 8 | baymak
# Processing Record 16 of Set 8 | bozoum
# Processing Record 17 of Set 8 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 18 of Set 8 | buta
# Processing Record 19 of Set 8 | warman
# Processing Record 20 of Set 8 | zyryanka
# Processing Record 21 of Set 8 | batemans bay
# Processing Record 22 of Set 8 | pacific grove
# Processing Record 23 of Set 8 | kotido
# Processing Record 24 of Set 8 | cabedelo
# Processing Record 25 of Set 8 | turbat
# Processing Record 26 of Set 8 | meulaboh
# Processing Record 27 of Set 8 | goure
# Processing Record 28 of Set 8 | atar
# Processing Record 29 of Set 8 | russell
# Processing Record 30 of Set 8 | tiarei
# Processing Record 31 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 8 | santiago del estero
# Processing Record 33 of Set 8 | nadym
# Processing Record 34 of Set 8 | camopi
# Processing Record 35 of Set 8 | lokosovo
# Processing Record 36 of Set 8 | tuatapere
# Processing Record 37 of Set 8 | spirovo
# Processing Record 38 of Set 8 | buala
# Processing Record 39 of Set 8 | akyab
# Processing Record 40 of Set 8 | marsh harbour
# Processing Record 41 of Set 8 | kholodnyy
# Processing Record 42 of Set 8 | gat
# Processing Record 43 of Set 8 | houston
# Processing Record 44 of Set 8 | porto novo
# Processing Record 45 of Set 8 | taltal
# Processing Record 46 of Set 8 | half moon bay
# Processing Record 47 of Set 8 | nelson bay
# Processing Record 48 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 8 | hereford
# Processing Record 50 of Set 8 | huarmey
# Processing Record 1 of Set 9 | bengkulu
# Processing Record 2 of Set 9 | utevka
# Processing Record 3 of Set 9 | merauke
# Processing Record 4 of Set 9 | college
# Processing Record 5 of Set 9 | hirara
# Processing Record 6 of Set 9 | sapa
# Processing Record 7 of Set 9 | neiafu
# Processing Record 8 of Set 9 | gushikawa
# Processing Record 9 of Set 9 | ostrovnoy
# Processing Record 10 of Set 9 | oktyabrskiy
# Processing Record 11 of Set 9 | moree
# Processing Record 12 of Set 9 | husavik
# Processing Record 13 of Set 9 | wittingen
# Processing Record 14 of Set 9 | naze
# Processing Record 15 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 9 | ryotsu
# Processing Record 17 of Set 9 | gilbues
# Processing Record 18 of Set 9 | vardo
# Processing Record 19 of Set 9 | sao luiz gonzaga
# Processing Record 20 of Set 9 | turayf
# Processing Record 21 of Set 9 | isangel
# Processing Record 22 of Set 9 | sturgis
# Processing Record 23 of Set 9 | riachao das neves
# Processing Record 24 of Set 9 | shizuishan
# Processing Record 25 of Set 9 | mount gambier
# Processing Record 26 of Set 9 | morondava
# Processing Record 27 of Set 9 | coahuayana
# Processing Record 28 of Set 9 | tazovskiy
# Processing Record 29 of Set 9 | bathsheba
# Processing Record 30 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 9 | esil
# Processing Record 32 of Set 9 | kavaratti
# Processing Record 33 of Set 9 | iquique
# Processing Record 34 of Set 9 | jalalabad
# Processing Record 35 of Set 9 | celestun
# Processing Record 36 of Set 9 | loudi
# Processing Record 37 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 38 of Set 9 | novobiryusinskiy
# Processing Record 39 of Set 9 | skibbereen
# Processing Record 40 of Set 9 | orgun
# City not found. Skipping...
# Processing Record 41 of Set 9 | vila velha
# Processing Record 42 of Set 9 | eyrarbakki
# Processing Record 43 of Set 9 | ust-kuyga
# Processing Record 44 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 45 of Set 9 | ugoofaaru
# Processing Record 46 of Set 9 | darhan
# Processing Record 47 of Set 9 | plettenberg bay
# Processing Record 48 of Set 9 | macusani
# Processing Record 49 of Set 9 | sulangan
# Processing Record 50 of Set 9 | misratah
# Processing Record 1 of Set 10 | matameye
# City not found. Skipping...
# Processing Record 2 of Set 10 | moncton
# Processing Record 3 of Set 10 | tsabong
# Processing Record 4 of Set 10 | redding
# Processing Record 5 of Set 10 | ilheus
# Processing Record 6 of Set 10 | longyearbyen
# Processing Record 7 of Set 10 | ulladulla
# Processing Record 8 of Set 10 | hervey bay
# Processing Record 9 of Set 10 | inhambane
# Processing Record 10 of Set 10 | champerico
# Processing Record 11 of Set 10 | nizhnyaya omka
# Processing Record 12 of Set 10 | nara
# Processing Record 13 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 14 of Set 10 | mitsamiouli
# Processing Record 15 of Set 10 | yatou
# Processing Record 16 of Set 10 | atka
# City not found. Skipping...
# Processing Record 17 of Set 10 | pisco
# Processing Record 18 of Set 10 | broome
# Processing Record 19 of Set 10 | sitka
# Processing Record 20 of Set 10 | amot
# Processing Record 21 of Set 10 | camana
# Processing Record 22 of Set 10 | te anau
# Processing Record 23 of Set 10 | nilanga
# Processing Record 24 of Set 10 | sobolevo
# Processing Record 25 of Set 10 | jieshi
# Processing Record 26 of Set 10 | ola
# Processing Record 27 of Set 10 | rundu
# Processing Record 28 of Set 10 | tieli
# Processing Record 29 of Set 10 | deer lake
# Processing Record 30 of Set 10 | kahului
# Processing Record 31 of Set 10 | pauini
# Processing Record 32 of Set 10 | kyzyl-suu
# Processing Record 33 of Set 10 | iralaya
# Processing Record 34 of Set 10 | port blair
# Processing Record 35 of Set 10 | conakry
# Processing Record 36 of Set 10 | palmer
# Processing Record 37 of Set 10 | swakopmund
# Processing Record 38 of Set 10 | castiglione delle stiviere
# Processing Record 39 of Set 10 | juneau
# Processing Record 40 of Set 10 | saint-denis
# Processing Record 41 of Set 10 | tisul
# Processing Record 42 of Set 10 | mandalgarh
# Processing Record 43 of Set 10 | tena
# Processing Record 44 of Set 10 | almaznyy
# Processing Record 45 of Set 10 | yulara
# Processing Record 46 of Set 10 | fangshan
# Processing Record 47 of Set 10 | ejura
# Processing Record 48 of Set 10 | evensk
# Processing Record 49 of Set 10 | mocuba
# Processing Record 50 of Set 10 | sur
# Processing Record 1 of Set 11 | manokwari
# Processing Record 2 of Set 11 | marquette
# Processing Record 3 of Set 11 | yenagoa
# Processing Record 4 of Set 11 | winton
# Processing Record 5 of Set 11 | sayat
# Processing Record 6 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 7 of Set 11 | mehamn
# Processing Record 8 of Set 11 | butembo
# Processing Record 9 of Set 11 | vega de alatorre
# Processing Record 10 of Set 11 | alofi
# Processing Record 11 of Set 11 | pangoa
# Processing Record 12 of Set 11 | chahuites
# Processing Record 13 of Set 11 | liaocheng
# Processing Record 14 of Set 11 | acarau
# Processing Record 15 of Set 11 | nyurba
# Processing Record 16 of Set 11 | jacareacanga
# Processing Record 17 of Set 11 | tagusao
# Processing Record 18 of Set 11 | baruun-urt
# Processing Record 19 of Set 11 | alta floresta
# Processing Record 20 of Set 11 | abha
# Processing Record 21 of Set 11 | terrace
# Processing Record 22 of Set 11 | flinders
# Processing Record 23 of Set 11 | kushiro
# Processing Record 24 of Set 11 | burica
# City not found. Skipping...
# Processing Record 25 of Set 11 | nioro
# Processing Record 26 of Set 11 | luwuk
# Processing Record 27 of Set 11 | lavrentiya
# Processing Record 28 of Set 11 | trogir
# Processing Record 29 of Set 11 | vicuna
# Processing Record 30 of Set 11 | koygorodok
# Processing Record 31 of Set 11 | marsa matruh
# Processing Record 32 of Set 11 | langsa
# Processing Record 33 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 11 | perth
# Processing Record 35 of Set 11 | benghazi
# Processing Record 36 of Set 11 | dukat
# Processing Record 37 of Set 11 | gonbad-e qabus
# Processing Record 38 of Set 11 | othonoi
# City not found. Skipping...
# Processing Record 39 of Set 11 | verkhnyaya toyma
# Processing Record 40 of Set 11 | sokolo
# Processing Record 41 of Set 11 | bardiyah
# Processing Record 42 of Set 11 | claresholm
# Processing Record 43 of Set 11 | auriflama
# Processing Record 44 of Set 11 | nome
# Processing Record 45 of Set 11 | tytuvenai
# Processing Record 46 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 11 | yerbogachen
# Processing Record 48 of Set 11 | kysyl-syr
# Processing Record 49 of Set 11 | zaysan
# Processing Record 50 of Set 11 | port hedland
# Processing Record 1 of Set 12 | kisangani
# Processing Record 2 of Set 12 | nabire
# Processing Record 3 of Set 12 | blagoyevo
# Processing Record 4 of Set 12 | tiznit
# Processing Record 5 of Set 12 | charters towers
# Processing Record 6 of Set 12 | dryden
# Processing Record 7 of Set 12 | warrensburg
# Processing Record 8 of Set 12 | dingle
# Processing Record 9 of Set 12 | kasaragod
# Processing Record 10 of Set 12 | natal
# Processing Record 11 of Set 12 | moranbah
# Processing Record 12 of Set 12 | wuwei
# Processing Record 13 of Set 12 | vangaindrano
# Processing Record 14 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 15 of Set 12 | sakakah
# Processing Record 16 of Set 12 | ornskoldsvik
# Processing Record 17 of Set 12 | caxito
# Processing Record 18 of Set 12 | pitimbu
# Processing Record 19 of Set 12 | ust-kut
# Processing Record 20 of Set 12 | lerici
# Processing Record 21 of Set 12 | maragogi
# Processing Record 22 of Set 12 | beisfjord
# Processing Record 23 of Set 12 | key largo
# Processing Record 24 of Set 12 | malinalco
# Processing Record 25 of Set 12 | thinadhoo
# Processing Record 26 of Set 12 | derzhavinsk
# Processing Record 27 of Set 12 | malakal
# Processing Record 28 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 12 | bay city
# Processing Record 30 of Set 12 | vanimo
# Processing Record 31 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 12 | port macquarie
# Processing Record 33 of Set 12 | raga
# Processing Record 34 of Set 12 | kalianget
# Processing Record 35 of Set 12 | tsuruoka
# Processing Record 36 of Set 12 | chulman
# Processing Record 37 of Set 12 | victor harbor
# Processing Record 38 of Set 12 | ayan
# Processing Record 39 of Set 12 | daitari
# Processing Record 40 of Set 12 | tortosa
# Processing Record 41 of Set 12 | marienburg
# Processing Record 42 of Set 12 | labuhan
# Processing Record 43 of Set 12 | pushkino
# Processing Record 44 of Set 12 | ivankiv
# Processing Record 45 of Set 12 | nanded
# City not found. Skipping...
# Processing Record 46 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 12 | aswan
# Processing Record 48 of Set 12 | lodwar
# Processing Record 49 of Set 12 | barra do garcas
# Processing Record 50 of Set 12 | higuey
# City not found. Skipping...
# Processing Record 1 of Set 13 | colares
# Processing Record 2 of Set 13 | ipeti
# City not found. Skipping...
# Processing Record 3 of Set 13 | biak
# Processing Record 4 of Set 13 | feijo
# Processing Record 5 of Set 13 | nicoya
# Processing Record 6 of Set 13 | turan
# Processing Record 7 of Set 13 | morehead
# Processing Record 8 of Set 13 | ixtapa
# Processing Record 9 of Set 13 | sorland
# Processing Record 10 of Set 13 | broken hill
# Processing Record 11 of Set 13 | namatanai
# Processing Record 12 of Set 13 | lomza
# Processing Record 13 of Set 13 | abnub
# Processing Record 14 of Set 13 | la rioja
# Processing Record 15 of Set 13 | north branch
# Processing Record 16 of Set 13 | mahajanga
# Processing Record 17 of Set 13 | umm kaddadah
# Processing Record 18 of Set 13 | tocopilla
# Processing Record 19 of Set 13 | sterling
# Processing Record 20 of Set 13 | ziro
# Processing Record 21 of Set 13 | saint anthony
# Processing Record 22 of Set 13 | basco
# Processing Record 23 of Set 13 | kizukuri
# Processing Record 24 of Set 13 | berezovyy
# Processing Record 25 of Set 13 | miandrivazo
# Processing Record 26 of Set 13 | zhangye
# Processing Record 27 of Set 13 | bjala
# City not found. Skipping...
# Processing Record 28 of Set 13 | raglan
# Processing Record 29 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 30 of Set 13 | biltine
# Processing Record 31 of Set 13 | lucea
# Processing Record 32 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 13 | bowen
# Processing Record 34 of Set 13 | homer
# Processing Record 35 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 13 | pucara
# Processing Record 37 of Set 13 | bubaque
# Processing Record 38 of Set 13 | ushtobe
# Processing Record 39 of Set 13 | shelburne
# Processing Record 40 of Set 13 | pecos
# Processing Record 41 of Set 13 | port lincoln
# Processing Record 42 of Set 13 | dasoguz
# Processing Record 43 of Set 13 | baoqing
# Processing Record 44 of Set 13 | xiongzhou
# Processing Record 45 of Set 13 | mariental
# Processing Record 46 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 47 of Set 13 | mizque
# Processing Record 48 of Set 13 | gizo
# Processing Record 49 of Set 13 | paka
# Processing Record 50 of Set 13 | hobyo
# Processing Record 1 of Set 14 | pafos
# Processing Record 2 of Set 14 | seoul
# Processing Record 3 of Set 14 | port-gentil
# Processing Record 4 of Set 14 | sun city west
# Processing Record 5 of Set 14 | emborion
# Processing Record 6 of Set 14 | kuching
# Processing Record 7 of Set 14 | bonthe
# Processing Record 8 of Set 14 | cockburn town
# Processing Record 9 of Set 14 | maxixe
# Processing Record 10 of Set 14 | hailun
# Processing Record 11 of Set 14 | sioux lookout
# Processing Record 12 of Set 14 | moron
# Processing Record 13 of Set 14 | stepnoye
# Processing Record 14 of Set 14 | rocha
# Processing Record 15 of Set 14 | kampene
# Processing Record 16 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 17 of Set 14 | touros
# Processing Record 18 of Set 14 | salalah
# Processing Record 19 of Set 14 | dunkwa
# Processing Record 20 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 14 | karaman
# Processing Record 22 of Set 14 | kudahuvadhoo
# Processing Record 23 of Set 14 | san policarpo
# Processing Record 24 of Set 14 | great falls
# Processing Record 25 of Set 14 | emba
# Processing Record 26 of Set 14 | praia
# Processing Record 27 of Set 14 | santa rosa
# Processing Record 28 of Set 14 | tual
# Processing Record 29 of Set 14 | noumea
# Processing Record 30 of Set 14 | adre
# Processing Record 31 of Set 14 | ancud
# Processing Record 32 of Set 14 | kununurra
# Processing Record 33 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 14 | guajara-mirim
# City not found. Skipping...
# Processing Record 35 of Set 14 | honiara
# Processing Record 36 of Set 14 | kachug
# Processing Record 37 of Set 14 | awjilah
# Processing Record 38 of Set 14 | ternate
# Processing Record 39 of Set 14 | stephenville
# Processing Record 40 of Set 14 | ginosa
# Processing Record 41 of Set 14 | beloha
# Processing Record 42 of Set 14 | sabang
# Processing Record 43 of Set 14 | olinda
# Processing Record 44 of Set 14 | trairi
# Processing Record 45 of Set 14 | fort collins
# Processing Record 46 of Set 14 | freeport
# Processing Record 47 of Set 14 | sembe
# Processing Record 48 of Set 14 | bima
# Processing Record 49 of Set 14 | maniitsoq
# Processing Record 50 of Set 14 | svetlyy
# Processing Record 1 of Set 15 | changji
# Processing Record 2 of Set 15 | kabanjahe
# Processing Record 3 of Set 15 | pimentel
# Processing Record 4 of Set 15 | muros
# Processing Record 5 of Set 15 | mayor pablo lagerenza
# Processing Record 6 of Set 15 | tabas
# Processing Record 7 of Set 15 | suihua
# Processing Record 8 of Set 15 | marrakesh
# Processing Record 9 of Set 15 | machico
# Processing Record 10 of Set 15 | noyabrsk
# Processing Record 11 of Set 15 | lugovoy
# Processing Record 12 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 13 of Set 15 | yei
# Processing Record 14 of Set 15 | marzuq
# Processing Record 15 of Set 15 | zapolyarnyy
# Processing Record 16 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 15 | tilichiki
# Processing Record 18 of Set 15 | hailar
# Processing Record 19 of Set 15 | tiffin
# Processing Record 20 of Set 15 | katangli
# Processing Record 21 of Set 15 | prainha
# Processing Record 22 of Set 15 | belmonte
# Processing Record 23 of Set 15 | narsaq
# Processing Record 24 of Set 15 | clermont
# Processing Record 25 of Set 15 | mayskiy
# Processing Record 26 of Set 15 | hoquiam
# Processing Record 27 of Set 15 | matay
# Processing Record 28 of Set 15 | pangkalanbuun
# Processing Record 29 of Set 15 | pueblo
# Processing Record 30 of Set 15 | valencia
# Processing Record 31 of Set 15 | xichang
# Processing Record 32 of Set 15 | calahorra
# Processing Record 33 of Set 15 | birjand
# Processing Record 34 of Set 15 | kaitong
# Processing Record 35 of Set 15 | requena
# Processing Record 36 of Set 15 | mufulira
# Processing Record 37 of Set 15 | jamsa
# Processing Record 38 of Set 15 | barda
# Processing Record 39 of Set 15 | nazare
# Processing Record 40 of Set 15 | olga
# Processing Record 41 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 42 of Set 15 | sabha
# Processing Record 43 of Set 15 | lubaczow
# Processing Record 44 of Set 15 | sirsi
# Processing Record 45 of Set 15 | santa maria
# Processing Record 46 of Set 15 | konya
# Processing Record 47 of Set 15 | calvinia
# Processing Record 48 of Set 15 | tomatlan
# Processing Record 49 of Set 15 | oranjemund
# Processing Record 50 of Set 15 | sattahip
# Processing Record 1 of Set 16 | baft
# Processing Record 2 of Set 16 | vidim
# Processing Record 3 of Set 16 | zhigansk
# Processing Record 4 of Set 16 | lhuntshi
# City not found. Skipping...
# Processing Record 5 of Set 16 | kiryas joel
# Processing Record 6 of Set 16 | chiang kham
# Processing Record 7 of Set 16 | kilindoni
# Processing Record 8 of Set 16 | tongzi
# Processing Record 9 of Set 16 | iskateley
# Processing Record 10 of Set 16 | udomlya
# Processing Record 11 of Set 16 | elizabethtown
# Processing Record 12 of Set 16 | beyneu
# Processing Record 13 of Set 16 | talara
# Processing Record 14 of Set 16 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 15 of Set 16 | iwanai
# Processing Record 16 of Set 16 | somerset west
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_weather_df = pd.DataFrame(city_data)
city_weather_df.head()
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tiksi      RU  71.69  128.87     37.85        85         100
# 1         Vao      NC -22.67  167.48     70.68        77           1
# 2       Kapit      MY   2.02  112.93     73.62        92          96
# 3        Yaan      NG   7.38    8.57     70.97        98          88
# 4  Novoagansk      RU  61.94   76.66     50.36        95         100
#
#    Wind Speed Current Description
# 0        9.53     overcast clouds
# 1        6.33           clear sky
# 2        0.43     overcast clouds
# 3        4.92     overcast clouds
# 4        5.12          light rain

# %%
city_weather_df.to_csv('WeatherPy_Database.csv,')
